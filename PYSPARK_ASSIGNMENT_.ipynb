# %%
# !pip install pyspark py4j
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (0.10.9.7)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("BigDataApp").getOrCreate()

# %%
#read csv
df = spark.read.csv("/content/IMDB Dataset (1).csv", header=True, inferSchema=True)
#header=True tells Spark to use the first row as column names.

#inferSchema=True automatically detects data types.

# %%
df
# Out:
# DataFrame[review: string, sentiment: string]

# %%
# Reading JSON
#df = spark.read.json("data.json")

# Reading Parquet
#df = spark.read.parquet("data.parquet")

# Hive (if enabled)
#df = spark.sql("SELECT * FROM hive_table")

# %% [markdown]
# #**New** **Section**

# %% [markdown]
# 3-inspecting and understanding data

# %%
df.show(5)         # Shows top 5 rows
df.printSchema()   # Prints the data schema
df.columns         # Returns list of column names
# Out:
# +--------------------+--------------------+
# |              review|           sentiment|
# +--------------------+--------------------+
# |One of the other ...|            positive|
# |"A wonderful litt...| not only is it w...|
# |"I thought this w...| but spirited you...|
# |Basically there's...|            negative|
# |"Petter Mattei's ...| power and succes...|
# +--------------------+--------------------+
# only showing top 5 rows
#
# root
#  |-- review: string (nullable = true)
#  |-- sentiment: string (nullable = true)
# ['review', 'sentiment']

# %%
df.show(n=df.count())
# Out:
# +--------------------+--------------------+
# |              review|           sentiment|
# +--------------------+--------------------+
# |One of the other ...|            positive|
# |"A wonderful litt...| not only is it w...|
# |"I thought this w...| but spirited you...|
# |Basically there's...|            negative|
# |"Petter Mattei's ...| power and succes...|
# |"Probably my all-...| but that only ma...|
# |I sure would like...|            positive|
# |This show was an ...|            negative|
# |Encouraged by the...|            negative|
# |If you like origi...|            positive|
# |"Phil the Alien i...|            negative|
# |I saw this movie ...|            negative|
# |"So im not a big ...| meaning most of ...|
# |The cast played S...|            negative|
# |This a fantastic ...|            positive|
# |Kind of drawn in ...|            negative|
# |Some films just s...|            positive|
# |This movie made i...|            negative|
# |I remember this f...|            positive|
# |An awful film! It...|            negative|
# |After the success...|            positive|
# |"I had the terrib...| it shouldn't eve...|
# |What an absolutel...|            positive|
# |"First of all, le...| too; the dinosau...|
# |This was the wors...|            negative|
# |The Karen Carpent...|            positive|
# |"""The Cell"" is ...| a dizzying trip ...|
# |This film tried t...|            negative|
# |"This movie was s...| the final scene ...|
# |"'War movie' is a...|"" starring Jude Law|
# |"Taut and organic...|                  DC|
# |"""Ardh Satya"" i...| this one is the ...|
# |"My first exposur...| but this alone c...|
# |"One of the most ...|     deliberate pace|
# |I watched this fi...|            negative|
# |"I bought this fi...| but Blockbuster ...|
# |The plot is about...|            negative|
# |Ever watched a mo...|            negative|
# |Okay, so this ser...|            positive|
# |"After sitting th...| etc. The fact th...|
# |It had all the cl...|            negative|
# |"This movie is ba...| a topic that com...|
# |"Of all the films...| but this is a su...|
# |"I had heard good...| and I thought th...|
# |This movie struck...|            positive|
# |As a disclaimer, ...|            positive|
# |Protocol is an im...|            negative|
# |"How this film co...| and Lot and Cana...|
# |Preston Sturgis' ...|            positive|
# |Average (and surp...|            negative|
# |"Return to the 36...| just like the go...|
# |"***SPOILERS*** A...| with his gang me...|
# |"I consider mysel...| but ""Gentleman ...|
# |"That this movie ...| Gibson and Downe...|
# |"Well, there's no...| but you're not m...|
# |This is the best ...|            negative|
# |Some people drift...|            positive|
# |Ho-hum. An invent...|            negative|
# |"Note to self. Ne...|            negative|
# |This movie is stu...|            negative|
# |"I was looking fo...| but vulgar."" <b...|
# |as always this is...|            negative|
# |i really in enjoy...|            positive|
# |"Having been a Ma...|   Full Metal Jacket|
# |Every high praise...|            positive|
# |"Ken Burns' ""Bas...| a great depictio...|
# |"""Quitting"" may...| class and succes...|
# |I have watched th...|            positive|
# |If only I had rea...|            negative|
# |Even though I saw...|            positive|
# |Gone is the wonde...|            negative|
# |"Although most Am...| though he is not...|
# |"Victor McLaglen'...| August's stunnin...|
# |"How do you take ...| Jean Reno or Fre...|
# |The sexploitation...|            positive|
# |What a surprising...|            positive|
# |"I did not expect...| but I did never ...|
# |I cant believe th...|            positive|
# |"Flynn, known mos...| but it's entirel...|
# |"Often laugh out ...|            positive|
# |"Thought provokin...| but very little ...|
# |Or anyone else ha...|            negative|
# |elvira mistress o...|            positive|
# |I saw this movie ...|            positive|
# |"Despite having a...| the most serious...|
# |I find the critiq...|            negative|
# |I was debating be...|            negative|
# |Bend it like Beck...|            positive|
# |Directed by Diane...|            negative|
# |Perhaps the most ...|            positive|
# |In sum, overlong ...|            negative|
# |"Incomprehensibly...| but beware - it'...|
# |Did anyone edit t...|            negative|
# |"Riding high on t...| came a tidal wav...|
# |Most of the comme...|            negative|
# |Pepe le Moko, pla...|            negative|
# |"Man with the Scr...| probably because...|
# |You should never ...|            negative|
# |Tell the truth I’...|            negative|
# |This film held my...|            positive|
# |"Like the previou...| why? Then they m...|
# |MAY CONTAIN SPOIL...|            negative|
# |"Watched this las...| but teens certai...|
# |"Recap: Something...| and the object e...|
# |This movie featur...|            negative|
# |"Had I checked IM...| an indication of...|
# |The endless bound...|            positive|
# |This flick is so ...|            negative|
# |This is a very me...|            positive|
# |"The plot: Michae...| whose real name ...|
# |It got to be a ru...|            positive|
# |"Years ago, when ...|     or in this case|
# |This series, made...|            negative|
# |I want the 99 min...|            negative|
# |One of my favorit...|            positive|
# |It's nice to see ...|            positive|
# |Of all the movies...|            positive|
# |"This is apparent...| ""Bob"" is playe...|
# |"This movie illus...| it brought nothi...|
# |"Owen loves his M...| even if it isn't...|
# |A Compelling Thri...|            positive|
# |"Filmfour are goi...|                 run|
# |Doctor Mordrid is...|            positive|
# |A truly muddled i...|            negative|
# |"It doesn't happe...| ""Good Time Char...|
# |"I'm a big fan of...| occasionally amu...|
# |"This ludicrous f...| innocent women w...|
# |This film was pre...|            positive|
# |For his first eve...|            positive|
# |This film contain...|            negative|
# |Pathetic attempt ...|            negative|
# |I was truly looki...|            negative|
# |One of my sisters...|            negative|
# |"Chuck Jones's 'R...|           as always|
# |A lovely little B...|            positive|
# |"""Crossfire"" is...|      Robert Mitchum|
# |AWWWW, I just lov...|            positive|
# |"Skippy from ""Fa...| a wussy 'metal' ...|
# |"This had a great...| that's the film ...|
# |I remember watchi...|            positive|
# |"I don't normally...|     but there I sat|
# |"Few would argue ...| turn them into p...|
# |Attractive Marjor...|            positive|
# |I find it sad tha...|            positive|
# |I watched this mo...|            negative|
# |For those out the...|            positive|
# |"THE GREAT CARUSO...| or 35c to 50c in...|
# |"I attended an ad...| this film was ex...|
# |"1) I am not weap...| not authentic ""...|
# |"Do you ever wond...|   "" ""entertaining|
# |"The film began w...| soon after they ...|
# |I was really hopi...|            negative|
# |"First of all ""M...| it sounded so st...|
# |"This movie is so...|              we win|
# |The symbolic use ...|            positive|
# |I found this movi...|            positive|
# |"Rather like Paul...| as he gets to sk...|
# |I would recommend...|            positive|
# |"This is an art f...|            negative|
# |I read the book a...|            positive|
# |"A drifter lookin...|"" the real hit m...|
# |I really liked th...|            positive|
# |"Although promote...| and gives ads to...|
# |Stan Laurel and O...|            negative|
# |"OK I have to adm...| more a case of a...|
# |I was -Unlike mos...|            positive|
# |"Just when I thou...| a friend brought...|
# |As is often the c...|            positive|
# |My father grew gr...|            positive|
# |This unpretentiou...|            positive|
# |I read the book b...|            positive|
# |Years ago, Sara, ...|            negative|
# |"In short if you ...| & it comes off g...|
# |I have watched Lo...|            positive|
# |The basic genre i...|            negative|
# |This is absolutel...|            positive|
# |Holes is an aweso...|            positive|
# |"I cannot hate on...| with 3 co-hosts ...|
# |Worst DCOM I have...|            negative|
# |its awful i cant ...|            negative|
# |"Some people may ...| but I wouldn't. ...|
# |So wonderful, so ...|            positive|
# |This film is, qui...|            positive|
# |"I have recently ...| some even leave ...|
# |In a time of bad,...|            positive|
# |PREY <br /><br />...|            negative|
# |The tourist seaso...|            positive|
# |"This review also...| this movie was a...|
# |This movie is rid...|            negative|
# |"In dramatising W...| but note that Wi...|
# |It starts out lik...|            negative|
# |"This is my first...| not her directio...|
# |"All the way thou...|"" but the acting...|
# |At 2:37, a high s...|            positive|
# |"The quote above ...| but decided I ou...|
# |Director Edward S...|            positive|
# |The jokes are obv...|            positive|
# |"These slasher pi...| but the story do...|
# |"The only reason ...| and it wasn't sh...|
# |Like most, I thou...|            positive|
# |"There are a coup...|"" which I've nev...|
# |"If you haven't s...| only the animals...|
# |"Why is it that C...|         bad writing|
# |Ab Tak Chhappan i...|            positive|
# |Let's keep it sim...|            positive|
# |"It was 1 a.m. in...| which gobbles up...|
# |Lackawanna Blues ...|            positive|
# |"Saturday June 3,...| allowing the pow...|
# |"As most people I...|            positive|
# |Many of the revie...|            positive|
# |"As the number of...| though if he ret...|
# |I rented this thi...|            negative|
# |"I found out abou...| I fail to see th...|
# |This movie has ev...|            positive|
# |Having just seen ...|            positive|
# |"The cast of this...| staged by your l...|
# |"Emily Watson and...| indeed. In spite...|
# |I am amazed with ...|            negative|
# |"Angela (Sandra B...|            positive|
# |I rented the DVD ...|            negative|
# |Look, this is a l...|            positive|
# |It wasn't until I...|            negative|
# |I am a huge Woody...|            positive|
# |"I rented this fi...| Illinois. It por...|
# |"1983's ""Frightm...| and the less-tha...|
# |People watch movi...|            positive|
# |I think that you ...|            negative|
# |"As usual, I am m...| go rent ""Full M...|
# |"A group of frien...| his brother who ...|
# |"Most Lorne Micha...|        for starters|
# |Having read durin...|            negative|
# |"Many teenage sex...| by all means tak...|
# |I loved this show...|            positive|
# |I didn't know wha...|            positive|
# |Did the first tra...|            negative|
# |I was never so bo...|            negative|
# |"This movie is aw...| get on with it""...|
# |"The Ladies Man i...|            positive|
# |when i first hear...|            positive|
# |A flying saucer m...|            positive|
# |"I just saw this ...| Robot"" has pola...|
# |This was a fine e...|            positive|
# |I have bought the...|            positive|
# |"This must have b...| or what is so sp...|
# |Liam Neeson portr...|            positive|
# |When i watch this...|            positive|
# |They've shown i t...|            negative|
# |"Having seen Carl...| the part about h...|
# |Time is precious....|            negative|
# |"worst. movie. ev...|            negative|
# |"Savage Island (2...| not some tired r...|
# |I have to say thi...|            positive|
# |I saw it at the L...|            positive|
# |"Adenoid Hynkel, ...| ruthless persecu...|
# |"""Milo"" is yet ...|he drowned but th...|
# |This is one of th...|            positive|
# |"Never saw the or...|            negative|
# |Created in 1928, ...|            positive|
# |Highly regarded a...|            positive|
# |"The perfect murd...|            negative|
# |The IMDb plot sum...|            negative|
# |"TESS OF THE STOR...| Mary the little ...|
# |I first saw this ...|            negative|
# |Although there ar...|            negative|
# |"Considering this...| as it appeared t...|
# |"The movie was ac...| he really kills ...|
# |"First, I realize...| as one reviewer ...|
# |"Picture the scen...| then walk away""...|
# |"The year 2005 sa...| but also to crea...|
# |Of the elements t...|            positive|
# |"Okay this is stu...|not that the next...|
# |"Everyone, my nam...| War of the world...|
# |"Finally was ther...| but if you stop ...|
# |"By now, the game...|            positive|
# |"I decided to wat...| it should be not...|
# |Unfortunately the...|            negative|
# |I Enjoyed Watchin...|            positive|
# |"Hypothetical sit...| I guess he does ...|
# |<br /><br />I mus...|            positive|
# |I am so happy not...|            positive|
# |"Like anyone else...| Rick Baker and G...|
# |I always felt tha...|            positive|
# |"This will not li...| another hit-man ...|
# |As a casual liste...|            negative|
# |Watch the Origina...|            negative|
# |Director Don Sieg...|            positive|
# |"Anyone who lived...| it's got a cast ...|
# |"Arguably the fin...|             rousing|
# |I have to say tha...|            positive|
# |Perfect movies ar...|            positive|
# |This has to be on...|            negative|
# |regardless of wha...|            negative|
# |"I want very much...| even when the ex...|
# |"It's hard to pra...| wondering what a...|
# |"I remember going...|              though|
# |Just finished wat...|            negative|
# |"I was watching t...| this still sucks...|
# |I only heard abou...|            positive|
# |"For Greta Garbo'...|"" the problem is...|
# |"Let me set the s...|         the scenery|
# |"As a long-time f...| both positive (a...|
# |This TV-series wa...|            positive|
# |"Fans of the HBO ...| will recognize t...|
# |Dirty War is abso...|            positive|
# |Some may go for a...|            negative|
# |"This is the Who ...|            positive|
# |"This filmmaker w...| the smallest fro...|
# |They filmed this ...|            positive|
# |That's how Burt R...|            positive|
# |Human Traffic is ...|            positive|
# |Send them to the ...|            positive|
# |Wow! I picked thi...|            positive|
# |I don't know why ...|            positive|
# |Mexican Werewolf ...|            negative|
# |I found this to b...|            positive|
# |I was so glad I c...|            positive|
# |I thought before ...|            negative|
# |"Truly appalling ...| ""you aren't goi...|
# |"In this movie, C...| Inspector Genera...|
# |"One could wish t...| but this is not ...|
# |"OK, so it owes P...| as is Mickey Rou...|
# |As far as I know ...|            positive|
# |"All I ever heard...| but it is the re...|
# |I do regret that ...|            negative|
# |The story has bee...|            positive|
# |This film was ver...|            negative|
# |As far as I know ...|            positive|
# |"Very typical Alm...|            positive|
# |"Once again, Doct...| but I do it bril...|
# |A Brother's Promi...|            positive|
# |"Well...now that ...|000 Corpses"" cra...|
# |Director Sidney L...|            positive|
# |I took my 14 year...|            negative|
# |I loved this film...|            positive|
# |"It's not easy to...| but it does have...|
# |"First of all, I ...| this film tells ...|
# |STMD! is not a te...|            negative|
# |First off, I have...|            negative|
# |"i am not exactly...| make it a priori...|
# |I must have seen ...|            positive|
# |Steven Seagal's f...|            negative|
# |"and I for one th...| I was glad to se...|
# |So real and surre...|            positive|
# |Thank God I watch...|            negative|
# |A friend lent me ...|            positive|
# |Shawshank, Godfat...|            positive|
# |I really cant thi...|            negative|
# |"Cinema's greates...| but each seems l...|
# |"This is a stereo...| but does not do ...|
# |This production w...|            positive|
# |"It isn't TOO bad...| this show is pre...|
# |"From the decrepi...| quite an ironic ...|
# |"As a huge baseba...|            positive|
# |This film takes y...|            positive|
# |Stupid! Stupid! S...|            negative|
# |This show is grea...|            positive|
# |"This film is whe...| as it turned out...|
# |"The Quick and th...| they have movies...|
# |I was stunned by ...|            positive|
# |Am I the only per...|            negative|
# |The one of the mo...|            positive|
# |This is the secon...|            positive|
# |It is always diff...|            positive|
# |This is one of my...|            positive|
# |"Let me first off...| thousands of rel...|
# |For a long time, ...|            positive|
# |Coen Brothers-wan...|            negative|
# |When it was relea...|            negative|
# |"Largely forgetta...| by depicting a r...|
# |Get Smart should ...|            negative|
# |Herculis Puaro is...|            negative|
# |How can so many b...|            negative|
# |This was by far t...|            negative|
# |"If you've read M...| Mother Night tel...|
# |"This is one of t...| that they touche...|
# |I sat through thi...|            negative|
# |A number of contr...|            positive|
# |Family problems a...|            positive|
# |The only conceiva...|            positive|
# |Salva and his pal...|            positive|
# |"These kinda movi...| or are wanting t...|
# |"As a big-time Pr...| I was really loo...|
# |"A good ol' boy f...| barefoot with sh...|
# |After several ext...|            positive|
# |But it is kinda h...|            positive|
# |One of the two Be...|            positive|
# |I managed to see ...|            positive|
# |"Why else would h...| and each cheesey...|
# |"Minimal script, ...| I know I am tryi...|
# |"A wonderful film...| and now ""Earl""...|
# |it got switched o...|            negative|
# |This is one of th...|            negative|
# |"(Only light spoi...| none of it is be...|
# |Yes, this is one ...|            negative|
# |Well where do I b...|            negative|
# |This is one of my...|            positive|
# |Following directl...|            positive|
# |Sometimes it's ha...|            positive|
# |"I had never seen...| ancient history....|
# |"Nothing is sacre...| just a little he...|
# |I hated it. I hat...|            negative|
# |"I usually try to...| redundant clips ...|
# |If you like me is...|            negative|
# |This is like a zo...|            negative|
# |This movie is awf...|            negative|
# |Why do movie make...|            negative|
# |I can't believe t...|            negative|
# |This film really ...|            positive|
# |Strangely enough ...|            positive|
# |"This film is so ...| and it is quite ...|
# |I don't leave IMD...|            negative|
# |"In Nordestina, a...| in a unique roma...|
# |"""I like cheap p...| after he gets a ...|
# |I am a huge fan o...|            positive|
# |"Based on the bes...|    The Missing Star|
# |This is sad this ...|            positive|
# |I found it very v...|            negative|
# |This movie is a r...|            negative|
# |I watch this movi...|            positive|
# |What a fun filled...|            positive|
# |Jackass Number Tw...|            positive|
# |"Turn your backs ...| and this ""Johnn...|
# |I remember the ev...|            positive|
# |"""Ally McBeal"" ...| but it was very ...|
# |Bad, ambient soun...|            negative|
# |"Okay so I love A...| or being forever...|
# |"You remember the...| ""Don't Stop Mov...|
# |I saw SEA OF DUST...|            positive|
# |This is a good ti...|            negative|
# |"I'm a Christian....| they did a hideo...|
# |"Having finally c...|"" it strikes me ...|
# |Thoughtless, igno...|            negative|
# |Jim Carrey is one...|            negative|
# |"Shameless Screen...|  ""My Dear Killer""|
# |"The key scene in...| hidden away in a...|
# |"MINOR PLOT SPOIL...| police!"" and ha...|
# |I can't really se...|            negative|
# |A major disappoin...|            negative|
# |I saw this movie ...|            negative|
# |"OK, how's this f...| if you're still ...|
# |L'Auberge Espagno...|            positive|
# |Make sure you mak...|            positive|
# |""" Så som i himm...| indeed several o...|
# |"At the height of...| the sedate Engli...|
# |"I am from Texas,...|             Phoenix|
# |"Mukhsin is a bea...| and favourite ou...|
# |The film is partl...|            positive|
# |"This could have ...|            negative|
# |A good documentar...|            positive|
# |Not the best plot...|            positive|
# |What a surprise; ...|            positive|
# |Felt it was very ...|            positive|
# |A proof that it's...|            positive|
# |I also saw this a...|            positive|
# |"The film ""Chaos...| the movie ""Choa...|
# |"I rented this mo...| ankle socks and ...|
# |Silent historical...|            positive|
# |As a camera opera...|            positive|
# |"I just saw this ...| hardworker while...|
# |"Duchess is a pre...| are lively and u...|
# |"Slipknot is a ha...| but the footage ...|
# |"The review on th...| both by a girl s...|
# |The movie plot se...|            negative|
# |It's 2005, my fri...|            negative|
# |Even with a cast ...|            negative|
# |"In the colonies ...|            moreover|
# |Probably New Zeal...|            negative|
# |Like the other co...|            negative|
# |To put it simply,...|            negative|
# |"The opening scen...| how did these gu...|
# |"In this day and ...| by any stretch o...|
# |"I've never laugh...|            positive|
# |The storyplot was...|            negative|
# |"My comment is ma...| or ""The Matrix"...|
# |"The DVD version ...| but the remainin...|
# |"Ahh, nuthin' lik...| ""The Erotic Hou...|
# |i happen to love ...|            positive|
# |Wow, i'm a huge H...|            negative|
# |It is hard to bel...|            negative|
# |"Must have to agr...|            negative|
# |In KPAX Softley b...|            positive|
# |After 15 minutes ...|            negative|
# |"I thought Rachel...| Kate"" and ""Vic...|
# |I have to say the...|            negative|
# |"I want Céline an...| i did believe th...|
# |"Lovely Candace B...| his predicament ...|
# |This movie is pat...|            negative|
# |...Or better yet,...|            negative|
# |Sharky's Machine ...|            positive|
# |Winchester '73 is...|            positive|
# |Peak Practice was...|            positive|
# ...
# |Highly flawed but...|            negative|
# |"I have seen this...| cause they would...|
# |"I never comment ...| but this was the...|
# |If Edward Woodwar...|            negative|
# |Warning--this fil...|            positive|
# |"I was the Produc...| still haunting p...|
# |"I suppose it dep...| when shows like ...|
# |Beethovan Lives U...|            negative|
# |"When I decided t...| I wasn't expecti...|
# |"I really wanted ...| comparable to Gr...|
# |"We have an avera...| the adopted whit...|
# |"""Sir"" John Gie...|           I suppose|
# |Apparently I am s...|            negative|
# |Some bad reviews ...|            positive|
# |The core issues a...|            negative|
# |I have to say thi...|            positive|
# |I'm guessing that...|            positive|
# |"I don't think th...|            negative|
# |Yes sure, this is...|            negative|
# |"Up until the las...|        Gene Hackman|
# |"the acting is go...|            negative|
# |"Like the above p...| Piranha!"" which...|
# |For once a Barbie...|            positive|
# |I was pleased to ...|            positive|
# |There are four gr...|            positive|
# |This movie is abs...|            negative|
# |Dumbland is not f...|            positive|
# |"(Review in Engli...| the writers shou...|
# |In Victorian time...|            positive|
# |When this film ge...|            positive|
# |What this film ha...|            negative|
# |"""Like the first...| like a spontaneo...|
# |"This is a weird ...| but I can see ho...|
# |"Although I am no...|            positive|
# |Tigerland follows...|            positive|
# |To all the review...|            positive|
# |"I really should ...|"" the lone black...|
# |Another one for t...|            positive|
# |I am a big fan of...|            negative|
# |This documentary ...|            negative|
# |The great cinemat...|            positive|
# |"They say David D...| because Pappas c...|
# |"I can safely adm...| it could ruin th...|
# |"I can not quite ...| the film did not...|
# |I just got back f...|            positive|
# |I had just reache...|            positive|
# |One of the worst ...|            negative|
# |...okay, maybe no...|            negative|
# |"Lets make a movi...|            negative|
# |"I saw the film y...| the plot was all...|
# |"I'm sorry to say...| and the fight se...|
# |As Most Off You M...|            positive|
# |"Really bad. Why ...|            negative|
# |This movie causes...|            negative|
# |I'm a fan of both...|            negative|
# |"This film wasn't...| the use of fluor...|
# |If you watched th...|            negative|
# |Back in the day i...|            positive|
# |"I have become a ...| I was captured b...|
# |"This movie is ab...| an international...|
# |"Let me start out...| but by the time ...|
# |When I first saw ...|            positive|
# |As a non-theist I...|            positive|
# |"Certainly this f...| but forget about...|
# |"""Hail The Woman...| and they will mi...|
# |Another French fi...|            negative|
# |As a member of th...|            negative|
# |"I was looking fo...| whether they be ...|
# |I enjoy quality c...|            negative|
# |This film had no ...|            negative|
# |The subject this ...|            negative|
# |"The Canterville ...| reciting Shakesp...|
# |"I am not so much...| the scene of the...|
# |This is absolutel...|            positive|
# |Killjoy 2 is the ...|            negative|
# |Officially the fi...|            negative|
# |"I saw Teen Devia...|        superb music|
# |"As a long-time f...| but I couldn't s...|
# |The Soloist has a...|            negative|
# |Jerry Angell, own...|            negative|
# |"I am sick of ser...|       self centered|
# |"Hmm I agree wit...| but it's ultimat...|
# |"Following which,...| ""Nuke em!""<br...|
# |Woa, talk about a...|            negative|
# |"Loved it! What's...|"" with Gibson di...|
# |"An unexpected pl...|            positive|
# |"When Melville's ...| his first public...|
# |"More than twenty...| in the land of M...|
# |One of the more l...|            positive|
# |This is a silly m...|            negative|
# |A country-boy Aus...|            positive|
# |Okay, I'll admit ...|            positive|
# |This is probably ...|            negative|
# |River's edge is n...|            positive|
# |I saw the preview...|            negative|
# |Wow. Not because ...|            negative|
# |"In a year of pre...| New York"" a fil...|
# |"The 1930s saw a ...| in which the ver...|
# |This film played ...|            positive|
# |Ho Hum. Just anot...|            negative|
# |I couldn't relate...|            negative|
# |If it is true tha...|            negative|
# |"Gosha's last gre...| many shots are i...|
# |"Usually, I start...| I'm not. In reality|
# |Thats not saying ...|            negative|
# |"The acting- fant...| which is by a pu...|
# |"My abiding love ...|"" has led me to ...|
# |"I really enjoy t...|            positive|
# |I confess to have...|            negative|
# |There is a lot of...|            positive|
# |I absolutely ador...|            positive|
# |"""National Velve...| a young English ...|
# |This is a beautif...|            positive|
# |You know, people ...|            positive|
# |Yes this movie fe...|            negative|
# |Before the releas...|            negative|
# |I found this movi...|            positive|
# |"to be honest, i ...| and it wasn't re...|
# |"This is an ""ant...| but is most famo...|
# |We went to the mo...|            negative|
# |"All things old a...|well you would ne...|
# |Wow, the spookies...|            negative|
# |"I'm a big horror...| I thought it loo...|
# |This is a good fi...|            positive|
# |"I haven't read t...| you are a big ol...|
# |"For the very rea...|               1998)|
# |STAR RATING: ****...|            positive|
# |"The apolitical m...| but when the war...|
# |I hated this show...|            negative|
# |A badly-acted two...|            negative|
# |This movie got ex...|            negative|
# |An under-apprecia...|            positive|
# |"Dont let the MPA...| however its just...|
# |"Immediately afte...| who wrote the sc...|
# |This has to be on...|            negative|
# |I saw this Film o...|            negative|
# |Threadbare horror...|            negative|
# |"Had it not been ...| but the underlyi...|
# |Totally disgustin...|            positive|
# |When reading a re...|            positive|
# |"Good things out ...|          an ""oh no|
# |There's a lot goi...|            positive|
# |Some have compare...|            positive|
# |"""The Brain Mach...| but it seems he'...|
# |To Die For has it...|            positive|
# |"Then you must se...| the stigma was i...|
# |"If you were ever...|"" then these thr...|
# |"I just caught th...| I might have giv...|
# |This movie is jus...|            negative|
# |"""If I sit down ...| that's what the ...|
# |This is a fascina...|            positive|
# |When this first c...|            positive|
# |"To most of us, l...| you see. And... ...|
# |I was surprised a...|            positive|
# |"Overrated mob co...| and he gets a no...|
# |No hidden agenda....|            positive|
# |The genre of susp...|            negative|
# |"This might be fo...|            negative|
# |"After seeing the...| I only got to se...|
# |"Ken Harrison, a ...|             that is|
# |"I've been a fan ...|               nasty|
# |Hedy Lamarr who m...|            negative|
# |"***SPOILERS!*** ...| though I persona...|
# |CitizenX(1995) is...|            positive|
# |"I happened to sp...|              anyhow|
# |'The Curse of Fra...|            negative|
# |I tried to give t...|            negative|
# |First things firs...|            negative|
# |"This movie is be...| where the two op...|
# |Return to Cabin b...|            negative|
# |"While I agree th...| Donna Reed was a...|
# |This movie gives ...|            positive|
# |It`s funny how in...|            negative|
# |"There is a lot t...|          as the mom|
# |Saw this movie at...|            positive|
# |<br /><br />Wheth...|            negative|
# |"This film center...| the Catholic sch...|
# |"This is one of t...| Wearing a comple...|
# |"Disjointed, uncl...| the story of Nor...|
# |OK, I would not n...|            positive|
# |Great characters,...|            positive|
# |I am a youth past...|            negative|
# |"The college teac...| believing that h...|
# |"Thirty years aft...| the feminist ant...|
# |James Hacker MP d...|            positive|
# |"I am a big fan o...|      House of blood|
# |Ever wonder where...|            positive|
# |"I'm Czech and so...| good special eff...|
# |Yeah i bought cam...|            negative|
# |"...""Flight of t...| can'tcha tell?""...|
# |I rented this mov...|            positive|
# |"In the opening s...|but ""Malta Story...|
# |There is a growin...|            negative|
# |The Brothers Quay...|            negative|
# |"There is NOTHING...|"" then we don't ...|
# |***May Contain Sp...|            positive|
# |I just saw this m...|            negative|
# |That Certain Thin...|            positive|
# |When you look at ...|            positive|
# |This is a really ...|            negative|
# |This was a pretty...|            positive|
# |Two redeeming qua...|            negative|
# |"The first time I...| who always gets ...|
# |My first impressi...|            positive|
# |"This movie has s...| so there was no ...|
# |The gates of Hell...|            negative|
# |I was never all t...|            positive|
# |Based on actual e...|            positive|
# |Great film about ...|            positive|
# |As a kid, I loved...|            positive|
# |So many fans, so ...|            negative|
# |As far as I can u...|            negative|
# |"That was a waste...| and did not seem...|
# |"I would give thi...| yet are also so ...|
# |... but I laughed...|            positive|
# |"I found this fil...|            negative|
# |"An ultra-modern ...| it is alive. But...|
# |"Tintin was one o...| and has brought ...|
# |Originally I rent...|            positive|
# |"""Hatred of a Mi...| but it's definit...|
# |"""Committed"" is...| upbeat comedic o...|
# |Ok, I've seen ple...|            negative|
# |I watched this on...|            positive|
# |When I saw this a...|            positive|
# |THE SHOP AROUND T...|            positive|
# |"When I go out to...| deranged homicid...|
# |"When I first saw...| I have shown it ...|
# |"For a low budget...|"" is sexier than...|
# |What a horrible m...|            negative|
# |Let's get some th...|            positive|
# |In a nutshell, sk...|            negative|
# |I just saw this m...|            positive|
# |"Sergei Eisenstei...| but they did a g...|
# |Low budget Brit p...|            positive|
# |"I'm shocked that...| still above aver...|
# |"As a ""lapsed Ca...| but hasn't been ...|
# |The viewer who sa...|            positive|
# |"The rumor is tru...| especially Cammi...|
# |"This movie start...|            distinct|
# |"Mt little sister...| don't waste your...|
# |I saw this film a...|            positive|
# |"This show is pai...|          boyfriends|
# |Probably the only...|            negative|
# |"Russ and Valerie...| who becomes awar...|
# |"A European music...| rock and hip-hop...|
# |"Viewed this GREA...|                 '39|
# |"I didn't expect ...|   parental conflict|
# |Man, this gets a ...|            negative|
# |This is without d...|            positive|
# |I liked this movi...|            positive|
# |I watched this mo...|            positive|
# |"One of the best ...|            positive|
# |"OK OK, it might ...| which makes sele...|
# |I saw this series...|            positive|
# |"It's a testament...| Torazo the Vagra...|
# |"Thanks to the he...| so somewhere som...|
# |I thought this mo...|            positive|
# |Michael Keaton ha...|            negative|
# |"One measurement ...| such an intellig...|
# |"Let's just say I...| especially the A...|
# |Well, here we hav...|            negative|
# |"Oh man, why? ""S...| it didn't caught...|
# |There has been a ...|            positive|
# |"The movie was ""...|            not good|
# |Not all movies ar...|            positive|
# |i just saw Dick T...|            negative|
# |The Haunting is a...|            positive|
# |I watched this la...|            positive|
# |Down to Earth is ...|            negative|
# |I have never read...|            positive|
# |"I was not nearly...| the script is ri...|
# |This movie starte...|            negative|
# |"Definitely an od...|            negative|
# |Charlie Wilson's ...|            positive|
# |"People are being...| who's lives ende...|
# |This Gundam serie...|            positive|
# +--------------------+--------------------+

# %%
df.describe().show()   # Summary stats (count, mean, stddev, min, max)
# Out:
# +-------+--------------------+--------------------+
# |summary|              review|           sentiment|
# +-------+--------------------+--------------------+
# |  count|               49885|               49878|
# |   mean|                NULL|              1392.0|
# | stddev|                NULL|   959.7489255008312|
# |    min|!!! Spoiler alert...| ! We are not stu...|
# |    max|ý thýnk uzak ýs t...|you don't just ha...|
# +-------+--------------------+--------------------+

# %% [markdown]
# 4.Data filtering and selection

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder.appName("IMDB Analysis").getOrCreate()

# Load the CSV into a PySpark DataFrame
df = spark.read.csv("IMDB Dataset (1).csv", header=True, inferSchema=True)

# Show selected columns
df.select("review", "sentiment").show(5)

# Filter rows where sentiment is positive
df.filter(df["sentiment"] == "positive").show(5)

# Filter rows using SQL-style string expression
df.where("sentiment = 'negative'").show(5)
# Out:
# +--------------------+--------------------+
# |              review|           sentiment|
# +--------------------+--------------------+
# |One of the other ...|            positive|
# |"A wonderful litt...| not only is it w...|
# |"I thought this w...| but spirited you...|
# |Basically there's...|            negative|
# |"Petter Mattei's ...| power and succes...|
# +--------------------+--------------------+
# only showing top 5 rows
#
# +--------------------+---------+
# |              review|sentiment|
# +--------------------+---------+
# |One of the other ...| positive|
# |I sure would like...| positive|
# |If you like origi...| positive|
# |This a fantastic ...| positive|
# |Some films just s...| positive|
# +--------------------+---------+
# only showing top 5 rows
#
# +--------------------+---------+
# |              review|sentiment|
# +--------------------+---------+
# |Basically there's...| negative|
# |This show was an ...| negative|
# |Encouraged by the...| negative|
# |"Phil the Alien i...| negative|
# |I saw this movie ...| negative|
# +--------------------+---------+
# only showing top 5 rows

# %% [markdown]
# 5- Group By and Aggregate

# %%
df.groupBy("sentiment").count().show()
# Out:
# +--------------------+-----+
# |           sentiment|count|
# +--------------------+-----+
# | ""Nightmare"" is...|    1|
# | he really kills ...|    1|
# | while others wil...|    1|
# | ""La Noche del T...|    1|
# |"" which apparent...|    1|
# |"" and felt a lit...|    1|
# |"" I think you wi...|    1|
# | a Spanish motion...|    1|
# | which has turned...|    1|
# | I suggest giving...|    1|
# | they come up wit...|    1|
# | one of the few h...|    1|
# | while a guy who ...|    1|
# | this is another ...|    1|
# | Andres is snoozi...|    1|
# |     you have chases|    1|
# | or other caper/h...|    1|
# | then this film i...|    1|
# | Israel is one of...|    1|
# | a bunch of lonel...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, length

# Start Spark session
spark = SparkSession.builder.appName("IMDB Review Analysis").getOrCreate()

# Load dataset
df = spark.read.csv("IMDB Dataset (1).csv", header=True, inferSchema=True)

# Add a new column: review_length
df = df.withColumn("review_length", length("review"))

# Group by sentiment and calculate average review length
df.groupBy("sentiment").agg(avg("review_length").alias("avg_review_length")).show()
# Out:
# +--------------------+-----------------+
# |           sentiment|avg_review_length|
# +--------------------+-----------------+
# | ""Nightmare"" is...|            100.0|
# | he really kills ...|            380.0|
# | while others wil...|             74.0|
# | ""La Noche del T...|            407.0|
# |"" which apparent...|            554.0|
# |"" and felt a lit...|             80.0|
# |"" I think you wi...|            296.0|
# | a Spanish motion...|            406.0|
# | which has turned...|             91.0|
# | I suggest giving...|            514.0|
# | they come up wit...|            481.0|
# | one of the few h...|            419.0|
# | while a guy who ...|           1005.0|
# | this is another ...|            347.0|
# | Andres is snoozi...|            497.0|
# |     you have chases|            320.0|
# | or other caper/h...|             51.0|
# | then this film i...|           2072.0|
# | Israel is one of...|            585.0|
# | a bunch of lonel...|            348.0|
# +--------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# 6-Modifying Columns

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, length

# Create Spark session
spark = SparkSession.builder.appName("IMDB Dataset Transformation").getOrCreate()

# Load dataset
df = spark.read.csv("IMDB Dataset (1).csv", header=True, inferSchema=True)

# Add a column for review length
df = df.withColumn("review_length", length(col("review")))

# Create a new column with 10% increased review length (just for demo purposes)
df = df.withColumn("increased_length", col("review_length") * 1.1)

# Show results
df.select("review", "sentiment", "review_length", "increased_length").show(5)
# Out:
# +--------------------+--------------------+-------------+------------------+
# |              review|           sentiment|review_length|  increased_length|
# +--------------------+--------------------+-------------+------------------+
# |One of the other ...|            positive|         1761|1937.1000000000001|
# |"A wonderful litt...| not only is it w...|          433|             476.3|
# |"I thought this w...| but spirited you...|          724| 796.4000000000001|
# |Basically there's...|            negative|          748| 822.8000000000001|
# |"Petter Mattei's ...| power and succes...|          200|220.00000000000003|
# +--------------------+--------------------+-------------+------------------+
# only showing top 5 rows

# %%
df = df.withColumnRenamed("review", "text").withColumnRenamed("sentiment", "label")
df.show(5)
# Out:
# +--------------------+--------------------+-------------+------------------+
# |                text|               label|review_length|  increased_length|
# +--------------------+--------------------+-------------+------------------+
# |One of the other ...|            positive|         1761|1937.1000000000001|
# |"A wonderful litt...| not only is it w...|          433|             476.3|
# |"I thought this w...| but spirited you...|          724| 796.4000000000001|
# |Basically there's...|            negative|          748| 822.8000000000001|
# |"Petter Mattei's ...| power and succes...|          200|220.00000000000003|
# +--------------------+--------------------+-------------+------------------+
# only showing top 5 rows

# %%
df = df.drop("review")
df.show(5)
# Out:
# +--------------------+--------------------+-------------+------------------+
# |                text|               label|review_length|  increased_length|
# +--------------------+--------------------+-------------+------------------+
# |One of the other ...|            positive|         1761|1937.1000000000001|
# |"A wonderful litt...| not only is it w...|          433|             476.3|
# |"I thought this w...| but spirited you...|          724| 796.4000000000001|
# |Basically there's...|            negative|          748| 822.8000000000001|
# |"Petter Mattei's ...| power and succes...|          200|220.00000000000003|
# +--------------------+--------------------+-------------+------------------+
# only showing top 5 rows

# %%
print(df.columns)
# Out:
# ['text', 'label', 'review_length', 'increased_length']

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import monotonically_increasing_id

# Start Spark session
spark = SparkSession.builder.appName("IMDB Join Example").getOrCreate()

# Load dataset
df1 = spark.read.csv("IMDB Dataset (1).csv", header=True, inferSchema=True)

# Add a synthetic ID column to both dataframes
df1 = df1.withColumn("id", monotonically_increasing_id())
df2 = df1.withColumnRenamed("review", "review_copy").withColumnRenamed("sentiment", "sentiment_copy")

# Perform inner join on 'id'
joined_df = df1.join(df2, df1.id == df2.id, "inner")

# Show some joined rows
joined_df.select("review", "review_copy", "sentiment", "sentiment_copy").show(5)
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |              review|         review_copy|           sentiment|      sentiment_copy|
# +--------------------+--------------------+--------------------+--------------------+
# |One of the other ...|One of the other ...|            positive|            positive|
# |"A wonderful litt...|"A wonderful litt...| not only is it w...| not only is it w...|
# |"Probably my all-...|"Probably my all-...| but that only ma...| but that only ma...|
# |I sure would like...|I sure would like...|            positive|            positive|
# |This show was an ...|This show was an ...|            negative|            negative|
# +--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Save DataFrame to CSV
df.write.mode("overwrite").csv("output/imdb_csv", header=True)

# Save DataFrame to Parquet
df.write.mode("overwrite").parquet("output/imdb_parquet")

# %%
from pyspark.sql import SparkSession

# Start Spark session
spark = SparkSession.builder.appName("IMDB SQL Query").getOrCreate()

# Load dataset
df = spark.read.csv("IMDB Dataset (1).csv", header=True, inferSchema=True)

# Register the DataFrame as a temporary SQL table
df.createOrReplaceTempView("imdb")

# Run SQL query: count number of positive and negative reviews
result = spark.sql("SELECT sentiment, COUNT(*) as total FROM imdb GROUP BY sentiment")
result.show()
# Out:
# +--------------------+-----+
# |           sentiment|total|
# +--------------------+-----+
# | ""Nightmare"" is...|    1|
# | he really kills ...|    1|
# | while others wil...|    1|
# | ""La Noche del T...|    1|
# |"" which apparent...|    1|
# |"" and felt a lit...|    1|
# |"" I think you wi...|    1|
# | a Spanish motion...|    1|
# | which has turned...|    1|
# | I suggest giving...|    1|
# | they come up wit...|    1|
# | one of the few h...|    1|
# | while a guy who ...|    1|
# | this is another ...|    1|
# | Andres is snoozi...|    1|
# |     you have chases|    1|
# | or other caper/h...|    1|
# | then this film i...|    1|
# | Israel is one of...|    1|
# | a bunch of lonel...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

spark = SparkSession.builder.appName("DataFrame vs RDD").getOrCreate()

# Create DataFrame from a list of numbers
df = spark.createDataFrame([(1,), (2,), (3,), (4,)], ["number"])

# Add a new column with squared values
df = df.withColumn("squared", col("number") * col("number"))

df.show()
# Out:
# +------+-------+
# |number|squared|
# +------+-------+
# |     1|      1|
# |     2|      4|
# |     3|      9|
# |     4|     16|
# +------+-------+
